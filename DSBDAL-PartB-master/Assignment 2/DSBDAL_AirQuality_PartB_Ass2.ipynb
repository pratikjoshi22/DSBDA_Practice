# %% [markdown]
# # Gruop B
# ## Assingment 2
# Name: Pranav Dandgaval
# T21136
# Div: 1
# ---
# PART B Ass 2 Perform the following operations using Python on the AirQuality / Heart Disease  data sets i) Data Cleaning ii)  Data Transformation iii) Data Integration iv) Error Correcting v) Model Building

# %%
import pandas as pd

# %%
df=pd.read_csv('AirQualityodisha.csv',delimiter=',')
df
# Out:
#       Stn Code Sampling Date   State           City  \
# 0           68      02-01-15  Odisha        Talcher
# 1           68      06-01-15  Odisha        Talcher
# 2           68      09-01-15  Odisha        Talcher
# 3           68      13-01-15  Odisha        Talcher
# 4           68      16-01-15  Odisha        Talcher
# ...        ...           ...     ...            ...
# 2387       819      15-12-15  Odisha  Kalinga Nagar
# 2388       819      17-12-15  Odisha  Kalinga Nagar
# 2389       819      22-12-15  Odisha  Kalinga Nagar
# 2390       819      26-12-15  Odisha  Kalinga Nagar
# 2391       819      29-12-15  Odisha  Kalinga Nagar
#
#      Location of Monitoring Station                                Agency  \
# 0           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# 1           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# 2           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Stn Code Sampling Date   State           City  \
# 0           68      02-01-15  Odisha        Talcher
# 1           68      06-01-15  Odisha        Talcher
# 2           68      09-01-15  Odisha        Talcher
# 3           68      13-01-15  Odisha        Talcher
# 4           68      16-01-15  Odisha        Talcher
# ...        ...           ...     ...            ...
# 2387       819      15-12-15  Odisha  Kalinga Nagar
# 2388       819      17-12-15  Odisha  Kalinga Nagar
# 2389       819      22-12-15  Odisha  Kalinga Nagar
# 2390       819      26-12-15  Odisha  Kalinga Nagar
# 2391       819      29-12-15  Odisha  Kalinga Nagar
#
#      Location of Monitoring Station                                Agency  \
# 0           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# 1           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# 2           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# ...

# %%
df.columns
# Out:
# Index(['Stn Code', 'Sampling Date', 'State', 'City',
#        'Location of Monitoring Station', 'Agency', 'Type of Location', 'SO2',
#        'NO2', 'RSPM/PM10', 'PM 2.5'],
#       dtype='object')

# %%
df.shape
# Out:
# (2392, 11)

# %%
#i) Data Cleaning ii)  Data Transformation

df.isnull().sum()
# Out:
# Stn Code                            0
# Sampling Date                       0
# State                               0
# City                                0
# Location of Monitoring Station      0
# Agency                              0
# Type of Location                    0
# SO2                                 0
# NO2                                 0
# RSPM/PM10                           0
# PM 2.5                            332
# dtype: int64

# %%
med=df['PM 2.5'].mean()
newdf=df['PM 2.5'].fillna(med)

print(newdf.isnull().sum())
# Out:
# 0

# %%
med
# Out:
# 42.47281553398058

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.3; however, version 22.1 is available.
# You should consider upgrading via the 'c:\users\pratik\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
#Data integration
import mysql.connector as con

# %%
try:
    mydb=con.connect(host='localhost',user='root',passwd='Pjstyles@1')
    print(mydb.is_connected())
    mydb.close()
except Exception as e:
    print(str(e))
# Out:
# True

# %%
try:
    mydb=con.connect(host='localhost',user='root',passwd='Pjstyles@1')
    print(mydb.is_connected())
    cursor=mydb.cursor() # cursor object is used to execute the SQL queries , it creates the pointer
    query="show databases"
    cursor.execute(query)
    print(cursor.fetchall())
    mydb.close()
except Exception as e:
    print(str(e))
# Out:
# True
# [('ecommerce_springboot',), ('information_schema',), ('mydb',), ('mysql',), ('performance_schema',), ('sakila',), ('sonoo',), ('studentmanage',), ('studentspring',), ('sys',), ('world',)]

# %%
query='create table testin.demotab(rollno int(10),name VARCHAR(10), addr VARCHAR(50),section VARCHAR(10))'
mydb=con.connect(host='localhost',user='root',passwd='Pjstyles@1')
print(mydb.is_connected())
cursor=mydb.cursor()
cursor.execute(query)
# Out:
# True

# %%
try:
    mydb=con.connect(host='localhost',user='root',passwd='Pjstyles@1')
    print(mydb.is_connected())
    cursor=mydb.cursor() # cursor object is used to execute the SQL queries , it creates the pointer
    query1="use testin"
    cursor.execute(query1)
    query2="show tables"
    cursor.execute(query2)
    print(cursor.fetchall())
    mydb.close()
except Exception as e:
    print(str(e))
# Out:
# True
# [('demotab',)]

# %%
try:
    mydb=con.connect(host='localhost',database='newglass',user='root',passwd='Pjstyles@1')
    print(mydb.is_connected())
    cursor=mydb.cursor() 
    query2="show databases"
    cursor.execute(query2)
    print(cursor.fetchall())
    mydb.close()
except Exception as e:
    print(str(e))
# Out:
# 1049 (42000): Unknown database 'newglass'

# %%
import mysql.connector as conn
import pandas as pd
import csv
try:
    mydb=conn.connect(host='localhost',user='root',passwd='mysql123',use_pure=True)
    print(mydb.is_connected())
    #query="create database glassdata1"
    #cursor=mydb.cursor()
    #cursor.execute(query)
    #print("Database created")
    mydb.close()
    mydb=conn.connect(host="localhost",database='newglass',user='root',passwd='mysql123',use_pure=True)
    query="create table if not exists glassdata11 (index_number INT(10),RI float (10,5),Na float(10,5),Mg float(10,5),Al float(10,5),Si float(10,5),K float(10,5),Ca float(10,5),Ba float(10,5),Fe float(10,5),Class int(10))"
    
    cursor=mydb.cursor()
    cursor.execute(query)
    print('table created')
    #load the data from file to database 
    with open('glass.data',"r") as f:
        next(f)
        glass_data=csv.reader(f,delimiter="\n")
        print(type(glass_data))
        for line in enumerate(glass_data):
            print(line)
            for list_ in (line[1]):
                print(list_)
                cursor.execute('insert into glassdata11 values ({values})'.format(values=list_))
        print("values inserted")
        mydb.commit()
        cursor.close()
        mydb.close()
except Exception as e:
    print(str(e))
# Out:
# True
# table created
# <class '_csv.reader'>
# (0, ['1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1'])
# 1,1.52101,13.64,4.49,1.10,71.78,0.06,8.75,0.00,0.00,1
# (1, ['2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1'])
# 2,1.51761,13.89,3.60,1.36,72.73,0.48,7.83,0.00,0.00,1
# (2, ['3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1'])
# 3,1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0.00,0.00,1
# (3, ['4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1'])
# 4,1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0.00,0.00,1
# (4, ['5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1'])
# 5,1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0.00,0.00,1
# (5, ['6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1'])
# 6,1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0.00,0.26,1
# (6, ['7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1'])
# 7,1.51743,13.30,3.60,1.14,73.09,0.58,8.17,0.00,0.00,1
# (7, ['8,1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0.00,0.00,1'])
# ...

# %%
import mysql.connector as con
import pandas as pd
try:
    mydb=con.connect(host='localhost',database='newglass',user='root',passwd='Pjstyles@1',use_pure=True)
    cursor=mydb.cursor()
    query1="use newglass"
    cursor.execute(query1)
    query="select * from glassdata11;"
        
    dataframe_result=pd.read_sql(query,mydb)
    print(dataframe_result)
    #mydb.close()
except Exception as e:
    print(str(e))
# Out:
# 1049 (42000): Unknown database 'newglass'

# %%
import mysql.connector as con
import pandas as pd
try:
    mydb=con.connect(host='localhost',database='newglass',user='root',passwd='mysql123',use_pure=True)
    cursor=mydb.cursor()
    query1="use newglass"
    cursor.execute(query1)
    query="select Si,Count(Si),Class from newglass.glassdata11 group by Class order by Si;"

    dataframe_result=pd.read_sql(query,mydb)
    print(dataframe_result)
    #mydb.close()
except Exception as e:
    print(str(e))
# Out:
#       Si  Count(Si)  Class
# 0  69.89         65      5
# 1  71.78        350      1
# 2  71.87        380      2
# 3  72.37         45      6
# 4  72.77         85      3
# 5  72.81        145      7

# %%
import sqlite3

# %%
db=sqlite3.connect('sample.db')

# %%
c=db.cursor()

# %%
c.execute('create table company2(id int,name text, age int,addr text,salary real)')

# %%
c.execute("insert into company1 values(1,'vsk',40,'sfdsf',90000)")

# %%
c.execute("insert into company1 values(2,'vsk2',32,'sfdsf',93000)")

# %%
data=c.execute("select * from company1")

# %%
for record in data:
    print(record)
# Out:
# (1, 'vsk', 40, 'sfdsf', 90000.0)
# (2, 'vsk2', 32, 'sfdsf', 93000.0)

# %%
#error correction
df=pd.read_csv('AirQualityodisha.csv',delimiter=',')
df_wna = df.dropna(subset=['PM 2.5'])
x=df['PM 2.5'].isnull().sum()
print("Total number of null values "+ str(x))
# Out:
# Total number of null values 332

# %%
df
# Out:
#       Stn Code Sampling Date   State           City  \
# 0           68      02-01-15  Odisha        Talcher
# 1           68      06-01-15  Odisha        Talcher
# 2           68      09-01-15  Odisha        Talcher
# 3           68      13-01-15  Odisha        Talcher
# 4           68      16-01-15  Odisha        Talcher
# ...        ...           ...     ...            ...
# 2387       819      15-12-15  Odisha  Kalinga Nagar
# 2388       819      17-12-15  Odisha  Kalinga Nagar
# 2389       819      22-12-15  Odisha  Kalinga Nagar
# 2390       819      26-12-15  Odisha  Kalinga Nagar
# 2391       819      29-12-15  Odisha  Kalinga Nagar
#
#      Location of Monitoring Station                                Agency  \
# 0           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# 1           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# 2           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# ...

# %%
x=df_wna['PM 2.5'].isnull().sum()
print("Total number of null values "+ str(x))
# Out:
# Total number of null values 0

# %%
df.columns
# Out:
# Index(['Stn Code', 'Sampling Date', 'State', 'City',
#        'Location of Monitoring Station', 'Agency', 'Type of Location', 'SO2',
#        'NO2', 'RSPM/PM10', 'PM 2.5'],
#       dtype='object')

# %%
df['so2_total']=df.groupby('City')['SO2'].transform('sum')

# %%
df.columns
# Out:
# Index(['Stn Code', 'Sampling Date', 'State', 'City',
#        'Location of Monitoring Station', 'Agency', 'Type of Location', 'SO2',
#        'NO2', 'RSPM/PM10', 'PM 2.5', 'so2_total'],
#       dtype='object')

# %%
df
# Out:
#       Stn Code Sampling Date   State           City  \
# 0           68      02-01-15  Odisha        Talcher
# 1           68      06-01-15  Odisha        Talcher
# 2           68      09-01-15  Odisha        Talcher
# 3           68      13-01-15  Odisha        Talcher
# 4           68      16-01-15  Odisha        Talcher
# ...        ...           ...     ...            ...
# 2387       819      15-12-15  Odisha  Kalinga Nagar
# 2388       819      17-12-15  Odisha  Kalinga Nagar
# 2389       819      22-12-15  Odisha  Kalinga Nagar
# 2390       819      26-12-15  Odisha  Kalinga Nagar
# 2391       819      29-12-15  Odisha  Kalinga Nagar
#
#      Location of Monitoring Station                                Agency  \
# 0           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# 1           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# 2           T.T.P.S.Colony, Talcher  Odisha State Pollution Control Board
# ...
