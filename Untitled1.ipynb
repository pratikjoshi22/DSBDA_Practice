# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('heart.csv')
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0        0      2.3      3  0.0       fixed   No
# 1        1      1.5      2  3.0      normal  Yes
# 2        1      2.6      2  2.0  reversable  Yes
# 3        0      3.5      3  0.0      normal   No
# 4        0      1.4      1  0.0      normal   No
# ..     ...      ...    ...  ...         ...  ...
# 298      0      1.2      2  0.0  reversable  Yes
# 299      0      3.4      2  2.0  reversable  Yes
# 300      1      1.2      2  1.0  reversable  Yes
# 301      0      0.0      2  1.0      normal  Yes
# 302      0      0.0      1  NaN      normal   No
#
# [303 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  303 non-null    int64
#  1   Age         303 non-null    int64
#  2   Sex         303 non-null    int64
#  3   ChestPain   303 non-null    object
#  4   RestBP      303 non-null    int64
#  5   Chol        303 non-null    int64
#  6   Fbs         303 non-null    int64
#  7   RestECG     303 non-null    int64
#  8   MaxHR       303 non-null    int64
#  9   ExAng       303 non-null    int64
#  10  Oldpeak     303 non-null    float64
#  11  Slope       303 non-null    int64
#  12  Ca          299 non-null    float64
#  13  Thal        301 non-null    object
#  14  AHD         303 non-null    object
# dtypes: float64(2), int64(10), object(3)
# memory usage: 35.6+ KB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Age', 'Sex', 'ChestPain', 'RestBP', 'Chol', 'Fbs',
#        'RestECG', 'MaxHR', 'ExAng', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'AHD'],
#       dtype='object')

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed   No
# 1        1.5      2  3.0      normal  Yes
# 2        2.6      2  2.0  reversable  Yes
# 3        3.5      3  0.0      normal   No
# 4        1.4      1  0.0      normal   No
# ..       ...    ...  ...         ...  ...
# 298      1.2      2  0.0  reversable  Yes
# 299      3.4      2  2.0  reversable  Yes
# 300      1.2      2  1.0  reversable  Yes
# 301      0.0      2  1.0      normal  Yes
# 302      0.0      1  NaN      normal   No
#
# [303 rows x 14 columns]

# %%
df['AHD']=df['AHD'].replace({"Yes":1,"No":0})
df
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed    0
# 1        1.5      2  3.0      normal    1
# 2        2.6      2  2.0  reversable    1
# 3        3.5      3  0.0      normal    0
# 4        1.4      1  0.0      normal    0
# ..       ...    ...  ...         ...  ...
# 298      1.2      2  0.0  reversable    1
# 299      3.4      2  2.0  reversable    1
# 300      1.2      2  1.0  reversable    1
# 301      0.0      2  1.0      normal    1
# 302      0.0      1  NaN      normal    0
#
# [303 rows x 14 columns]

# %%
df['Sex'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.countplot(df["Sex"])
# Out:
# c:\users\pratik\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
fig=plt.figure(figsize=(20,10))
sns.boxplot(data = df,notch = True,linewidth = 2.5, width = 0.50)
plt.show()
# Out:
#   File "C:\Users\PRATIK\AppData\Local\Temp/ipykernel_17372/1096101447.py", line 2
#     sns.boxplot(data = df,subplots=True,,linewidth = 2.5, width = 0.50)
#                                         ^
# SyntaxError: invalid syntax

# %%
df.plot(subplots=True,sharex=True,layout=(6,2),figsize=(16,8))
plt.tight_layout() # 2 rows and 3 cols

# %%
df.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(kind='box', subplots=True, layout=(2,7), sharex=False,sharey=False, figsize=(20, 10), 
color='red');

# %%
sns.boxplot(x='AHD',y='Oldpeak',data=df)
# Out:
# <AxesSubplot:xlabel='AHD', ylabel='Oldpeak'>

# %%
df['Age'].hist().plot(kind='bar')
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
df['Oldpeak'].hist().plot(kind='bar')
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
df['Oldpeak'].hist().plot(kind='bar') plt.title('Age Distribution')
# Out:
#   File "C:\Users\PRATIK\AppData\Local\Temp/ipykernel_17372/3276239596.py", line 1
#     df['Oldpeak'].hist().plot(kind='bar') plt.title('Age Distribution')
#                                           ^
# SyntaxError: invalid syntax

# %%
print(df.Age.value_counts()[:10])
sns.barplot(x=df.Age.value_counts()[:10].index,
y=df.Age.value_counts()[:10].values,
palette='Set2')
plt.xlabel('Age')
plt.ylabel('Age distribution')
# Out:
# 58    19
# 57    17
# 54    16
# 59    14
# 52    13
# 60    12
# 51    12
# 56    11
# 62    11
# 44    11
# Name: Age, dtype: int64
# Text(0, 0.5, 'Age distribution')

# %%
name = df['Sex']
ax = sns.countplot(x='Sex', hue='AHD', data=df, palette='Set1')

# %%
fig, ax = plt.subplots(figsize=(10,5))
name = df['ChestPain']
ax = sns.countplot(x='ChestPain', hue='AHD', data=df, palette='Set2')

# %%
minAge =min(df["Age"])
maxAge =max(df["Age"])
avgAge = (df["Age"]).mean()
print("Minimum age:",minAge)
print("Maximum age:",maxAge)
print("Average age:",avgAge)
# Out:
# Minimum age: 29
# Maximum age: 77
# Average age: 54.43894389438944

# %%
teen_age = df[(df.Age>=10)&(df.Age<19)]
Young_age = df[(df.Age>=29)&(df.Age<40)]
Meddle_age = df[(df.Age>=40)&(df.Age<55)]
Elderly_age = df[(df.Age>55)]

# %%
sns.barplot(x = ["teen_age","Young ages","Meddle Ages","Elderly ages"], y =[len(teen_age),len(Young_age),len(Meddle_age),len(Elderly_age)], color = "red")
# Out:
# <AxesSubplot:>

# %%
f,ax=plt.subplots(1,2,figsize=(10,6))
df["AHD"].value_counts().plot.pie(ax = ax[1],autopct='%1.1f%%')
sns.countplot('AHD',data=df,ax=ax[0],order=df['Sex'].value_counts().index)
# Out:
# c:\users\pratik\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AHD', ylabel='count'>

# %%
f,ax=plt.subplots(1,2,figsize=(10,6))
df["AHD"].value_counts().plot.pie(ax = ax[0],autopct='%1.1f%%')
sns.countplot('AHD',data=df,ax=ax[1],order=df['Sex'].value_counts().index)
# Out:
# c:\users\pratik\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AHD', ylabel='count'>

# %%
f,ax=plt.subplots(1,2,figsize=(10,6))
df["ChestPain"].value_counts().plot.pie(ax = ax[0],autopct='%1.1f%%')
sns.countplot('ChestPain',data=df,ax=ax[1],order=df['Sex'].value_counts().index)
# Out:
# c:\users\pratik\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ChestPain', ylabel='count'>

# %%
sns.countplot(df["AHD"])
# Out:
# c:\users\pratik\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AHD', ylabel='count'>

# %%
corr = df.corr()
corr
# Out:
#               Age       Sex    RestBP      Chol       Fbs   RestECG     MaxHR  \
# Age      1.000000 -0.097542  0.284946  0.208950  0.118530  0.148868 -0.393806
# Sex     -0.097542  1.000000 -0.064456 -0.199915  0.047862  0.021647 -0.048663
# RestBP   0.284946 -0.064456  1.000000  0.130120  0.175340  0.146560 -0.045351
# Chol     0.208950 -0.199915  0.130120  1.000000  0.009841  0.171043 -0.003432
# Fbs      0.118530  0.047862  0.175340  0.009841  1.000000  0.069564 -0.007854
# RestECG  0.148868  0.021647  0.146560  0.171043  0.069564  1.000000 -0.083389
# MaxHR   -0.393806 -0.048663 -0.045351 -0.003432 -0.007854 -0.083389  1.000000
# ExAng    0.091661  0.146201  0.064762  0.061310  0.025665  0.084867 -0.378103
# Oldpeak  0.203805  0.102173  0.189171  0.046564  0.005747  0.114133 -0.343085
# Slope    0.161770  0.037533  0.117382 -0.004062  0.059894  0.133946 -0.385601
# Ca       0.362605  0.093185  0.098773  0.119000  0.145478  0.128343 -0.264246
# AHD      0.223120  0.276816  0.150825  0.085164  0.025264  0.169202 -0.417167
#
#             ExAng   Oldpeak     Slope        Ca       AHD
# Age      0.091661  0.203805  0.161770  0.362605  0.223120
# Sex      0.146201  0.102173  0.037533  0.093185  0.276816
# RestBP   0.064762  0.189171  0.117382  0.098773  0.150825
# Chol     0.061310  0.046564 -0.004062  0.119000  0.085164
# Fbs      0.025665  0.005747  0.059894  0.145478  0.025264
# RestECG  0.084867  0.114133  0.133946  0.128343  0.169202
# MaxHR   -0.378103 -0.343085 -0.385601 -0.264246 -0.417167
# ExAng    1.000000  0.288223  0.257748  0.145570  0.431894
# Oldpeak  0.288223  1.000000  0.577537  0.295832  0.424510
# Slope    0.257748  0.577537  1.000000  0.110119  0.339213
# Ca       0.145570  0.295832  0.110119  1.000000  0.460442
# AHD      0.431894  0.424510  0.339213  0.460442  1.000000

# %%
plt.figure(figsize =(20,15))
sns.heatmap(corr,annot= True)
# Out:
# <AxesSubplot:>
